# %% [markdown]
# ![DataDunkers.ca Banner](https://github.com/Data-Dunkers/lessons/blob/main/images/top-banner.jpg?raw=true)

# %% [markdown]
# # Analyse de Data Dunkers : fr2
#
# Ce cahier nous permettra d'analyser les donn?es que nous avons recueillies ? l'aide du [formulaire Google](https://docs.google.com/forms/d/e/1FAIpQLSeYOp7MzQNFgm3oVNqmL-fjlPZ_ZmTFt53865c2Sx1n__1u_g/viewform).
#
# La premi?re ?tape consiste ? importer les donn?es recueillies. Cliquez sur la cellule ci-dessous, puis sur le bouton de lecture.

# %%
import pandas as pd
df = pd.read_csv('https://docs.google.com/spreadsheets/d/1YH1m0Oo8r1sY0iOZE5eJOhNpkGqDrYmuDbN1rEy80Xk/export?format=csv')

df

# %% [markdown]
# Maintenant que vous avez les donn?es, ex?cutez la cellule de code suivante pour calculer la moyenne (mean) des ? Tirs r?ussis ? pour chaque distance.

# %%
distance = df.columns[2]
moyenne = df.groupby(distance)['Tirs r?ussis'].mean()

moyenne

# %% [markdown]
# Vous pouvez ex?cuter la cellule suivante pour afficher toutes les initiales saisies dans le formulaire.

# %%
print(df['Initiales'].unique())

# %% [markdown]
# ## Graphiques
#
# Ex?cutez la cellule de code suivante pour cr?er un diagramme ? b?tons ? partir de ces moyennes calcul?es.

# %%
import plotly.express as px
px.bar(averages, y='Tirs r?ussis', title='Moyenne des tirs r?ussis pour chaque distance')

# %% [markdown]
# ## Filtrage
# Vous pouvez ?galement utiliser uniquement vos donn?es. Modifiez la cellule de code ci-dessous en rempla?ant `PS43` par l?identifiant que vous avez ?crit dans le formulaire.
#
# Ex?cutez ensuite la cellule de code pour filtrer le cadre de donn?es (data frame) afin qu'il ne contienne que vos donn?es.

# %%
moi = 'PS43'

mes = df[df[df.columns[1]] == moi]
mes

# %% [markdown]
# Maintenant que tes donn?es sont stock?es dans la variable `mes`, utilise la cellule de code suivante pour cr?er un diagramme ? b?tons de tes tirs r?ussis.

# %% [markdown]
# ## La fin
#
# F?licitations, tu as termin? ce cahier d'activit?s ! J'esp?re que ces exemples t'aideront ? cr?er tes propres graphiques.
#
# D?couvre d'autres ressources sur [DataDunkers.ca/fr](https://datadunkers.ca/fr).

# %% [markdown]
# [![Data Dunkers License](https://github.com/Data-Dunkers/lessons/blob/main/images/bottom-banner.jpg?raw=true)](https://github.com/Data-Dunkers/lessons/blob/main/LICENSE.md)
