# %% [markdown]
# # Data Dunkers Analysis - Student Course
#
# This notebook will allow us to analyse the data we collected using the [Google Form](https://docs.google.com/forms/d/e/1FAIpQLSfr4DybteJ3keaEHO8GL79gH_oEKkIV0P8gL1CTMo9UD4jW8A/viewform).
#
# The first step is to import the collected data. Click on the cell below then click the play button on the left.

# %% [markdown]
# # Data Dunkers - Simple Form Data Analysis
# df = pd.read_csv('https://docs.google.com/spreadsheets/d/1WQkl5Aj6PKoXHLGxaX-XBPe_Ds5jRFExPHTavbwrKV0/export?format=csv')
# The first step is to import the data we collected. Click on the cell below and click the play button on the left.

# %%
import pandas as pd
df = pd.read_csv(csv_url)

df

# %% [markdown]
# Now that you have the data, run the following code cell to calculate the average (`mean`) of `Shots made` at each distance.

# %%
distance = df.columns[2]
averages = df.groupby(distance)['Shots made'].mean()

averages

# %% [markdown]
# You can run the next cell to see all of the initials that were entered on the form.

# %%
print(df['Initials'].unique())

# %% [markdown]
# ## Graphing
#
# Run the following code cell to make a bar chart from those calculated averages.

# %%
import plotly.express as px
px.bar(averages, y='Shots made', title='Average Shots Made at Each Distance')

# %% [markdown]
# ## Filtering
#
# You can also use just your data. Edit the code cell below by replacing the `PS43` with how you identified yourself on the form.
#
# Then run the code cell to filter the data frame to include just your data.

# %%
me = 'PS43'

initials_column = df.columns[1]
my_data = df[df[initials_column] == me]
my_data

# %% [markdown]
# Now that you have your data stored in the variable `my_data`, use the following code cell to make a bar graph of your shots made.

# %% [markdown]
# ## The End
#
# Congratulations, you have completed this notebook. Hopefully you can use these examples to create your own graphs.
#
# Check out other resources at [DataDunkers.ca](https://datadunkers.ca).
#
# You can also try [chart.misterhay.com](https://chart.misterhay.com) for generating graphs and Python code.

# %% [markdown]
# [![Data Dunkers License](https://github.com/Data-Dunkers/lessons/blob/main/images/bottom-banner.jpg?raw=true)](https://github.com/Data-Dunkers/lessons/blob/main/LICENSE.md)
